# %% [markdown]
# <a href="https://colab.research.google.com/github/Amrith96/workshop/blob/main/Day_4%2B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

print(uploaded)
# Out:
#      <input type="file" id="files-6e7bb10b-ac58-4622-b5bc-6b23e44c744b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6e7bb10b-ac58-4622-b5bc-6b23e44c744b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance.csv
# ...

# %%
# !ls
# Out:
# sample_data  StudentsPerformance.csv

# %%
import pandas as pd

# %%
students = pd.read_csv("StudentsPerformance.csv")
students.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
students.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
students.plot.scatter("writing score" , "parental level of education" , figsize=(9, 3))

# %%
df = students

# %%
import seaborn as sns
import matplotlib.pyplot as plt

xData = [x for x in range(10)]
yData = [y for y in range(20)]
sns.lineplot(x="writing score",y="reading score",data=df) 
plt.show()

# %%
std = df

# %%
import seaborn as sns
sns.countplot(std['gender'] , orient='h')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-411d7fa2ebc4> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.countplot(df['gender'] , orient='h')
#
# NameError: name 'df' is not defined
